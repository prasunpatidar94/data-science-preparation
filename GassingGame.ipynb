# %% [markdown]
# <a href="https://colab.research.google.com/github/prasunpatidar94/data-science-preparation/blob/main/GassingGame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as RD


givenNumber = int (input("koi bhi ek Number Dade : "))
gasNumber = int (input("koi bhi numder gas kar : "))
count = 1

while givenNumber != gasNumber:
  if givenNumber > gasNumber:
    count = count + 1
    gasNumber = int(input("gas number incorrect .. it is lower then actual number: "))
    print(" you have taken ", count , "attempts..!")
  elif givenNumber < gasNumber:
    count = count + 1
    gasNumber = int(input("gas number incorrect .. it is grater then actual number: "))
    print(" you have taken ", count , "attempts..!")

else:
  print("yow won ....! correct gas number is : ", gasNumber)
# Out:
# koi bhi ek Number Dade : 42
# koi bhi numder gas kar : 5
# gas number incorrect .. it is lower then actual number: 24
#  you have taken  2 attempts..!
# gas number incorrect .. it is lower then actual number: 52
#  you have taken  3 attempts..!
# gas number incorrect .. it is grater then actual number: 26
#  you have taken  4 attempts..!
# gas number incorrect .. it is lower then actual number: 15
#  you have taken  5 attempts..!
# gas number incorrect .. it is lower then actual number: 26
#  you have taken  6 attempts..!
# gas number incorrect .. it is lower then actual number: 25
#  you have taken  7 attempts..!
# gas number incorrect .. it is lower then actual number: 46
#  you have taken  8 attempts..!
# gas number incorrect .. it is grater then actual number: 42
#  you have taken  9 attempts..!
# yow won ....! correct gas number is :  42
